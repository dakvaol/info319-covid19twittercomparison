# %%
#Notebook to extract data from the datasets

import pandas as pd

#Chosing a dataset
#Run all cells and change parameters to write different files
df = pd.read_csv('..//useddata/03-24-2020.csv')
df.head(25)
# Out:
#        FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0   45001.0  Abbeville  South Carolina             US  2020-03-24 23:37:31
# 1   22001.0     Acadia       Louisiana             US  2020-03-24 23:37:31
# 2   51001.0   Accomack        Virginia             US  2020-03-24 23:37:31
# 3   16001.0        Ada           Idaho             US  2020-03-24 23:37:31
# 4   19001.0      Adair            Iowa             US  2020-03-24 23:37:31
# 5   21001.0      Adair        Kentucky             US  2020-03-24 23:37:31
# 6   29001.0      Adair        Missouri             US  2020-03-24 23:37:31
# 7   40001.0      Adair        Oklahoma             US  2020-03-24 23:37:31
# 8    8001.0      Adams        Colorado             US  2020-03-24 23:37:31
# 9   16003.0      Adams           Idaho             US  2020-03-24 23:37:31
# 10  17001.0      Adams        Illinois             US  2020-03-24 23:37:31
# ...

# %%
info = df

#May need to remove, 'Incidence_Rate', 'Case-Fatality_Ratio' for the earliest datasets. 
drop = info.drop(columns=['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update', 'Confirmed', 'Deaths', 'Recovered', 'Incidence_Rate', 'Case-Fatality_Ratio'])
drop.head()
# Out:
#          Lat       Long_  Active                   Combined_Key
# 0  34.223334  -82.461707   136.0  Abbeville, South Carolina, US
# 1  30.295065  -92.414197  1050.0          Acadia, Louisiana, US
# 2  37.767072  -75.632346  1028.0         Accomack, Virginia, US
# 3  43.452658 -116.241552  3408.0                 Ada, Idaho, US
# 4  41.330756  -94.471059    17.0                Adair, Iowa, US

# %%
drop.to_csv('confirmed_08jul.csv',index=False)

# %%
infocheck = pd.read_csv('info_extended.csv')

# %%
infocheck.head()
# Out:
#         Lat      Long_   Active Combined_Key
# 0  33.93911  67.709953   5072.0  Afghanistan
# 1  41.15330  20.168300   6101.0      Albania
# 2  28.03390   1.659600  14301.0      Algeria
# 3  42.50630   1.521800   1261.0      Andorra
# 4 -11.20270  17.873900   3976.0       Angola
